# %%
import pandas as pd
df=pd.read_csv("train.csv")
print(df.head())
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
print(df.head())
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
print(df.head(10))
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ...

# %%
print(df.tail(10))
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10989  10990               B             Ship                    5
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10993  10994               F             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10989                1                  218                5
# 10990                4                  219                6
# ...

# %%
print("columns:",df.shape[1])
# Out:
# columns: 12

# %%
print(df.isnull().sum())
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
print(df['Warehouse_block'].nunique())
# Out:
# 5

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    5545
# M    5454
# Name: count, dtype: int64

# %%
print(df['Warehouse_block'].head(3))
# Out:
# 0    D
# 1    F
# 2    A
# Name: Warehouse_block, dtype: object

# %%
df['Customer_rating'].mean()
# Out:
# np.float64(2.9905445949631786)

# %%
df['Reached.on.Time_Y.N'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 10994    1
# 10995    0
# 10996    0
# 10997    0
# 10998    0
# Name: Reached.on.Time_Y.N, Length: 10999, dtype: int64>

# %% [raw]
# print("Average cost:",df['cost_of_the_product'].mean())

# %%
import pandas as pd
df=pd.read_csv("train.csv")
print(df.head())
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
print(df['Customer_rating'].nunique())
# Out:
# 5

# %%
print(df.head())
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# ...

# %%
print(df.head(10))
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# ...

# %%
print(df.tail(10))
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10989  10990               B             Ship                    5
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10993  10994               F             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10989                1                  218                5
# 10990                4                  219                6
# ...

# %%
print("columns:",df.shape[1])
# Out:
# columns: 12

# %%
print(df.isnull().sum())
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Gender
# F    5545
# M    5454
# Name: count, dtype: int64

# %%
print(df['Warehouse_block'].head(3))
# Out:
# 0    D
# 1    F
# 2    A
# Name: Warehouse_block, dtype: object

# %%
df['Customer_rating'].mean()
# Out:
# np.float64(2.9905445949631786)

# %%
df['Customer_rating'].mean()
# Out:
# np.float64(2.9905445949631786)

# %%
print(df['Product_importance'].unique())
# Out:
# ['low' 'medium' 'high']
