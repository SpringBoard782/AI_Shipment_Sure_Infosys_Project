# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

df = pd.read_csv(r"C:\Users\simpi\OneDrive\Desktop\datasetexplore\archive (1)\Train.csv")

# %%
# 1. Dataset shape
df.shape

# %%
# 2. Preview first 5 rows
df.head()

# %%
# 3. Column names
df.columns

# %%
# 4. Data types
df.dtypes

# %%
df.describe()

# %%
df.info()

# %%
df.isnull().sum()

# %%
(df.isnull().mean() * 100).round(2)

# %%
df.duplicated().sum()

# %%
df['Gender'].unique()

# %%
df['Gender'].nunique()

# %%
df['Gender'].value_counts()

# %%
df['Warehouse_block'].mode()

# %%
df['Mode_of_Shipment'].value_counts().head(5)

# %%
df['Mode_of_Shipment'].value_counts().tail(5)

# %%
# 1. Unique ages
df['Customer_care_calls'].unique()

# %%
# 2. Number of unique age groups
df['Customer_care_calls'].nunique()

# %%
# 3. Unique
df['Customer_care_calls'].unique()

# %%
df['Customer_rating'].nunique()

# %%
df['Customer_rating'].unique()[:10]

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='Gender', data=df)
plt.title('Gender Distribution')

# %%
sns.countplot(x='Mode_of_Shipment', data=df)  # Try with underscore instead of space
plt.title('Mode_of_Shipment')

# %%
sns.countplot(x='Marital_Status', data=df)
plt.title('Marital Status')

# %%
sns.scatterplot(x='Product_importance', y='Reached.on.Time_Y.N', data=df)
plt.title('Product_importance vs Reached.on.Time_Y.N')

# %%
sns.barplot(x='Product_importance', y='Reached.on.Time_Y.N', data=df, estimator=sum, errorbar=None)
plt.title('Sales by Product Category')
plt.xticks(rotation=45)

# %%
top_states = df.groupby('Prior_purchases')['Discount_offered'].sum().sort_values(ascending=False).head(10)
top_states.plot(kind='bar', title='Top 10 States by Spending')

# %%
sns.heatmap(df[['Weight_in_gms', 'Prior_purchases', 'Discount_offered']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')

# %%
sns.boxplot(x='Warehouse_block', y='Mode_of_Shipment', data=df)
plt.xticks(rotation=45)

# %%
sns.histplot(df['Warehouse_block'], bins=20, kde=True)

# %%
# 1. Descriptive stats for numerical columns
df[['Warehouse_block', 'Mode_of_Shipment', 'Discount_offered']].describe()

# %%
df['Discount_offered'].corr(df['Weight_in_gms'])

# %%
# 2. Correlation matrix
numeric_columns = ['Discount_offered']
df[numeric_columns].corr()

# %%
df['Discount_offered'].corr(df['Cost_of_the_Product'])

# %%
df['Discount_offered'].var()

# %%
df['Prior_purchases'].std()

# %%
(df['Discount_offered'] / df['Prior_purchases']).mean()

# %%
df['Weight_in_gms'].max() - df['Weight_in_gms'].min()

# %%
df['Prior_purchases'].median()

# %%
df['Cost_of_the_Product'].skew()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')

# %%
df['SpendPerOrder'] = df['Reached.on.Time_Y.N'] / df['Customer_care_calls']

# %%
df['HighSpender'] = (df['Reached.on.Time_Y.N'] > df['Customer_care_calls'].quantile(0.75)).astype(int)

# %%
df['Reached.on.Time_Y.N'] = pd.cut(df['Customer_care_calls'], bins=[0, 5, 10, 100], labels=['Low', 'Medium', 'High'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['Product_importance'] = scaler.fit_transform(df[['Customer_rating']])
